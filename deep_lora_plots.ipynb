# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import json
import os

import numpy as np
import plot_utils
import matplotlib.pyplot as plt
# Out:
# 2024-01-27 01:38:00.563509: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-27 01:38:00.563561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-27 01:38:00.564908: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-27 01:38:01.706468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
fig = plot_utils.plot_fewshot_1024_results()
fig.savefig("figures/deep_lora_1024.png", bbox_inches="tight", dpi=500)

# %%
fig = plot_utils.plot_narrow_vs_wide_results()
fig.savefig("figures/deep_lora_narrow_vs_wide.png", bbox_inches="tight", dpi=500)

# %%
fig = plot_utils.plot_fewshot_stsb_results()
fig.savefig("figures/fewshot_stsb.png", bbox_inches="tight", dpi=500)
