# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import os

import numpy as np
import plot_utils
import matplotlib.pyplot as plt

# %%
fig = plot_utils.plot_fewshot_1024_results()
fig.savefig("figures/deep_lora_1024.png", bbox_inches="tight", dpi=500)

# %%
fig = plot_utils.plot_narrow_vs_wide_results()
fig.savefig("figures/deep_lora_narrow_vs_wide.png", bbox_inches="tight", dpi=500)

# %%
eval_values, sample_sizes = plot_utils.get_fewshot_stsb_results()

# %%
[np.mean(y) for y in [x[0] for x in eval_values]]
# Out:
# [0.6092489757313497, 0.7401088290174916, 0.827304835852995]

# %%
[np.mean(y) for y in [x[1] for x in eval_values]]
# Out:
# [0.5450175859790171, 0.7203652467762437, 0.8133385054919264]

# %%
fig, ax = plt.subplots()
ax.errorbar(sample_sizes, eval_values[0][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 ax.errorbar(sample_sizes, eval_values[0][0])
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# ...

# %%
eval_values
# Out:
# [(array([0.63238857, 0.55895704, 0.63102976, 0.63175876, 0.53065094,
#          0.67586246, 0.54332214, 0.64281505, 0.68251059, 0.56319444]),
#   array([0.58527928, 0.47098859, 0.61725194, 0.55188536, 0.4704211 ,
#          0.6331536 , 0.47363117, 0.55870896, 0.54652025, 0.5423356 ])),
#  (array([0.73145571, 0.78396779, 0.74326822, 0.73695634, 0.76066412,
#          0.67440383, 0.78700752, 0.75582969, 0.73198831, 0.69554674]),
#   array([0.72996754, 0.75775907, 0.72841988, 0.65330594, 0.74497434,
#          0.67663558, 0.76908508, 0.74646082, 0.72303155, 0.67401266])),
#  (array([0.82982747, 0.83982967, 0.82826605, 0.82482202, 0.82318644,
#          0.82132321, 0.8286863 , 0.82922537, 0.83113109, 0.81675075]),
#   array([0.81323963, 0.82176407, 0.82171331, 0.8012707 , 0.83175257,
#          0.80477662, 0.81801202, 0.80589583, 0.8209303 , 0.79403   ]))]

# %%
for x in eval_values:
    print(np.mean(x))
# Out:
# 0.06423138975233281
# 0.01974358224124807
# 0.013966330361068546
